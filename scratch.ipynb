# %%
import pandas as pd

# %%
df_test = pd.read_parquet("df_test.parquet")
df_val = pd.read_parquet("df_val.parquet")
df_train= pd.read_parquet("df_train.parquet")
df =pd.read_parquet("filtered.parquet")
rq3_filtered = ("rq3_filtered.parquet")

# %%
import j_process

# %%
# Out:
#   CVDINFR4 CVDCRHD4 CVDSTRK3                             ASTHMA3 CHCSCNC1  \
# 0       No       No       No  No -  Go to Section 07.06 CHCSCNC1       No
# 1       No       No       No  No -  Go to Section 07.06 CHCSCNC1       No
# 2       No       No       No                                 Yes       No
# 3       No       No       No  No -  Go to Section 07.06 CHCSCNC1      Yes
# 4       No       No       No  No -  Go to Section 07.06 CHCSCNC1       No
#
#   CHCOCNC1 CHCCOPD3 CHCKDNY2 HAVARTH4                       DIABETE4  ...  \
# 0       No       No       No       No                            Yes  ...
# 1       No       No       No      Yes  No -  Go to Section 08.01 AGE  ...
# 2       No       No       No      Yes  No -  Go to Section 08.01 AGE  ...
# 3      Yes       No       No      Yes  No -  Go to Section 08.01 AGE  ...
# 4      Yes       No       No      Yes                            Yes  ...
#
#   DIFFALON                           SMOKE100  \
# 0       No  No -  Go to Section 12.03 USENOW3
# 1       No  No -  Go to Section 12.03 USENOW3
# 2       No                                Yes
# 3       No  No -  Go to Section 12.03 USENOW3
# 4      Yes  No -  Go to Section 12.03 USENOW3
#
#                                       ECIGNOW2  \
# 0  Never used e-cigarettes in your entire life
# 1  Never used e-cigarettes in your entire life
# 2  Never used e-cigarettes in your entire life
# 3  Never used e-cigarettes in your entire life
# 4  Never used e-cigarettes in your entire life
#
#                              FLUSHOT7 PNEUVAC4 SEATBELT  \
# 0  No -  Go to Section 13.03 PNEUVAC4       No   Always
# 1                                 Yes      Yes   Always
# 2                                 Yes      Yes   Always
# 3                                 Yes      Yes   Always
# 4  No -  Go to Section 13.03 PNEUVAC4      Yes   Always
#
#                                    COVIDPO1    GENHLTH  \
# 0  No -  Go to Modules or Closing Statement  Very good
# 1  No -  Go to Modules or Closing Statement  Very good
# 2  No -  Go to Modules or Closing Statement       Fair
# 3  No -  Go to Modules or Closing Statement  Very good
# 4  No -  Go to Modules or Closing Statement       Fair
#
#                              EXERANY2 TOLDHI3
# 0  No -  Go to Section 04.08 STRENGTH      No
# 1                                 Yes     Yes
# 2                                 Yes     Yes
# 3                                 Yes      No
# 4                                 Yes      No
#
# [5 rows x 26 columns]
